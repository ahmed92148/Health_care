# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmed92148/Health_care/blob/master/image_class_oct_4_working.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the drive
from google.colab import drive
drive.mount('/content/drive')

# %%
#importing the required packages
from fastai.vision import *
from fastai.metrics import error_rate

# %%
cd drive/My\ Drive
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive'
# /content/drive/My Drive

# %%
path = Path('data/bears')
dest = path/'black'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'teddy'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'grizzly'
dest.mkdir(parents=True, exist_ok=True)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".",valid_pct = 0.2, ds_tfms=get_transforms(), size=224).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddy']

# %%
data.show_batch(rows=4, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'teddy'], 3, 88, 21)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.100013</td>
#       <td>0.679559</td>
#       <td>0.238095</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.811460</td>
#       <td>0.000500</td>
#       <td>0.000000</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.223359</td>
#       <td>0.000062</td>
#       <td>0.000000</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.909958</td>
#       <td>0.000022</td>
#       <td>0.000000</td>
#       <td>00:59</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1') #pickle_file! save in google drive and create a download link
